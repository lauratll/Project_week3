# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#1.-100-HOT-songs:-Create-DB" data-toc-modified-id="1.-100-HOT-songs:-Create-DB-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>1. 100 HOT songs: Create DB</a></span><ul class="toc-item"><li><span><a href="#1.1.-Scrapping-web-Hot-100-Songs-to-obtain-the-Hot-Song-initial-DB" data-toc-modified-id="1.1.-Scrapping-web-Hot-100-Songs-to-obtain-the-Hot-Song-initial-DB-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>1.1. Scrapping web Hot 100 Songs to obtain the Hot Song initial DB</a></span></li><li><span><a href="#1.2.-100-HOT-songs:-implement-audio-features--API-Spotify" data-toc-modified-id="1.2.-100-HOT-songs:-implement-audio-features--API-Spotify-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>1.2. 100 HOT songs: implement audio features- API Spotify</a></span></li><li><span><a href="#1.3.-Get-ID's-from-Hot-Songs" data-toc-modified-id="1.3.-Get-ID's-from-Hot-Songs-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>1.3. Get ID's from Hot Songs</a></span></li><li><span><a href="#1.3.2.-Get-audio-feaures-for-all-ID's-for-our-Hot-Songs" data-toc-modified-id="1.3.2.-Get-audio-feaures-for-all-ID's-for-our-Hot-Songs-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>1.3.2. Get audio feaures for all ID's for our Hot Songs</a></span></li><li><span><a href="#2.4.-Merging-audio-features-with-previous-DF-for-Hot-Songs" data-toc-modified-id="2.4.-Merging-audio-features-with-previous-DF-for-Hot-Songs-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>2.4. Merging audio features with previous DF for Hot Songs</a></span></li></ul></li><li><span><a href="#3.-Spotify:-Create-DB" data-toc-modified-id="3.-Spotify:-Create-DB-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>3. Spotify: Create DB</a></span><ul class="toc-item"><li><span><a href="#3.1.-Retrive-tracks-from-playlist" data-toc-modified-id="3.1.-Retrive-tracks-from-playlist-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>3.1. Retrive tracks from playlist</a></span></li><li><span><a href="#3.2.-Get-audio-features-for-playlist" data-toc-modified-id="3.2.-Get-audio-features-for-playlist-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>3.2. Get audio features for playlist</a></span></li><li><span><a href="#3.3.-Put-all-together" data-toc-modified-id="3.3.-Put-all-together-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>3.3. Put all together</a></span></li></ul></li><li><span><a href="#3.-PUT-BOTH-DB-TOGETHER-FOR-K-MEANS-AND-GET-LABELS" data-toc-modified-id="3.-PUT-BOTH-DB-TOGETHER-FOR-K-MEANS-AND-GET-LABELS-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>3. PUT BOTH DB TOGETHER FOR K-MEANS AND GET LABELS</a></span><ul class="toc-item"><li><span><a href="#3.1.-Concatenate-data-frames" data-toc-modified-id="3.1.-Concatenate-data-frames-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>3.1. Concatenate data frames</a></span></li><li><span><a href="#5.2-Select-the-audio-features-interested-(train-model-in-another-file)" data-toc-modified-id="5.2-Select-the-audio-features-interested-(train-model-in-another-file)-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>5.2 Select the audio features interested (train model in another file)</a></span></li><li><span><a href="#4.4-Add-labels-and-export-each-DB" data-toc-modified-id="4.4-Add-labels-and-export-each-DB-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>4.4 Add labels and export each DB</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Project Week 3 - Desired music recommender

# %% [markdown]
# ## 1. 100 HOT songs: Create DB

# %% [markdown]
# We are gonna create a function to scrape the [Billaboards 100 HOT songs](https://www.billboard.com/charts/hot-100) and create a local dataframe of songs with them inluding:
#
# - Song's name
# - Song's artist
#
# After we will parse Spotify's API to get audio features for this songs and their Id.

# %%
# 1. import libraries
import requests # to download html code
from bs4 import BeautifulSoup # to navigate through the html code
import pandas as pd
import numpy as np
import re

# %%
# 2. find url and store it in a variable
url = "https://www.billboard.com/charts/hot-100"

# %%
# 3. download html with a get request. Use the function request.get() and store the output in response
response = requests.get(url)
# 200 status code means OK! response.status_code
print(response.status_code)
# Out:
# 200

# %%
# 4.1. parse html (create the 'soup')
soup = BeautifulSoup(response.text, 'html.parser')
# 4.2. check that the html code looks like it should
#print(soup.prettify())#it is too much, so I will skip this

# %% [markdown]
# ### 1.1. Scrapping web Hot 100 Songs to obtain the Hot Song initial DB

# %%
def scrapp_hotsongs():
    url = "https://www.billboard.com/charts/hot-100"
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    titles_songs = soup.find_all("span", {"class": "chart-element__information__song text--truncate color--primary"})
    songs = [elem.get_text() for elem in titles_songs]
    artists_names = soup.find_all("span", {"class": "chart-element__information__artist"})
    artists = [elem.get_text() for elem in artists_names]
    return songs, artists

def obtain_hotsong_db(list_of_list):
    songs,artists = list_of_list
    dic_songs = {"title": songs, "artist": artists}
    hot_songs = pd.DataFrame(dic_songs)
    return hot_songs

# %%
hot_songs = obtain_hotsong_db(scrapp_hotsongs())

# %% [markdown]
# ### 1.2. 100 HOT songs: implement audio features- API Spotify

# %% [markdown]
# Before that we will need to get credentials for our account. Create a python file with the credentials store in the same folder, but remember to include this file on your gitignore to don't share it after on your repo.

# %%
#Access to my file with the Credentials
import sys
sys.path.insert(1, "/Users/lauratll/Documents/Data_Analysis/IronHack/Week_3/Project_Week_3/Credentials/")
from config import *

# %%
#Import the requested libraries to work
#The installer: conda install -c conda-forge spotipy

import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
import pprint

# %%
#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= Client_ID,
                                                           client_secret= Client_Secret))

# %% [markdown]
# ### 1.3. Get ID's from Hot Songs

# %%
#We need to use our lists of Hot Songs, We will get arttis name, id and name of the song from the Tiles

list_hot_songs = hot_songs["title"].to_list()
# list_hot_artists = hot_songs["Artist"].to_list()

#track_info = sp.search(q=list_hot_songs)
#pprint.pprint(track_info)

# %%
def get_id_name_title_from_track(tracks_list):
    '''
    With this function we get the ids, names and artist of all out songs in the initial Db from the web scrapping.
    We will input a list of the titles of the songs.
    We will get the artist to make sure we have all the information propertly to be able to after pass those
    to the function that will get the audio features.
    Input: list of all the name of the songs
    Ouput: a list for id, another for names, another for artist
    '''
    list_id = [] 
    list_names = []
    list_artists = []
    for track in tracks_list:
        track_info = sp.search(q=track,limit=1)
#         seconds_to_wait = randint(2,7)
#         sleep(seconds_to_wait)
        track_id = track_info["tracks"]["items"][0]["id"]
        track_name = track_info["tracks"]["items"][0]["name"]
        track_artist = track_info["tracks"]["items"][0]["artists"]
        track_artist2 =[elem["name"] for elem in track_artist]
        track_artist3 = ", ".join(track_artist2)
        list_id.append(track_id)
        list_names.append(track_name)
        list_artists.append(track_artist3)
    return list_id,list_names,list_artists

# %%
id_hot,title_hot,artist_hot = get_id_name_title_from_track(list_hot_songs)

# %% [markdown]
# ### 1.3.2. Get audio feaures for all ID's for our Hot Songs

# %%
audio_features_info= sp.audio_features(tracks=id_hot)
# audio_features_info

# %%
hot_extra_features = pd.DataFrame(audio_features_info)
hot_extra_features["SongId"] = id_hot
hot_extra_features["title"] = title_hot
hot_extra_features["artists"] = artist_hot

# %%
hot_extra_features.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.759   0.459    8    -5.187     1       0.0948       0.00323
# 1         0.556   0.661    6    -5.052     0       0.2040       0.30000
# 2         0.702   0.825    6    -3.787     0       0.0601       0.00883
# 3         0.677   0.696    0    -6.181     1       0.1190       0.32100
# 4         0.586   0.616    5    -7.964     1       0.0324       0.18200
#
#    instrumentalness  liveness  valence  ...            type  \
# 0               0.0    0.0906    0.695  ...  audio_features
# 1               0.0    0.1010    0.668  ...  audio_features
# 2               0.0    0.0674    0.915  ...  audio_features
# 3               0.0    0.4200    0.464  ...  audio_features
# 4               0.0    0.0927    0.719  ...  audio_features
#
#                        id                                   uri  \
# 0  2bgTY4UwhfBYhGT4HUYStN  spotify:track:2bgTY4UwhfBYhGT4HUYStN
# 1  6PERP62TejQjgHu81OHxgM  spotify:track:6PERP62TejQjgHu81OHxgM
# 2  463CkQjx2Zk1yXoBuierM9  spotify:track:463CkQjx2Zk1yXoBuierM9
# 3  4iJyoBOLtHqaGxP12qzhQI  spotify:track:4iJyoBOLtHqaGxP12qzhQI
# 4  7MAibcTli4IisCtbHKrGMh  spotify:track:7MAibcTli4IisCtbHKrGMh
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/2bgTY4UwhfBY...
# 1  https://api.spotify.com/v1/tracks/6PERP62TejQj...
# 2  https://api.spotify.com/v1/tracks/463CkQjx2Zk1...
# 3  https://api.spotify.com/v1/tracks/4iJyoBOLtHqa...
# 4  https://api.spotify.com/v1/tracks/7MAibcTli4Ii...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/2bgT...      164442
# 1  https://api.spotify.com/v1/audio-analysis/6PER...      178148
# 2  https://api.spotify.com/v1/audio-analysis/463C...      203064
# 3  https://api.spotify.com/v1/audio-analysis/4iJy...      198082
# 4  https://api.spotify.com/v1/audio-analysis/7MAi...      242096
#
#    time_signature                  SongId  \
# 0               4  2bgTY4UwhfBYhGT4HUYStN
# 1               4  6PERP62TejQjgHu81OHxgM
# 2               4  463CkQjx2Zk1yXoBuierM9
# 3               4  4iJyoBOLtHqaGxP12qzhQI
# 4               4  7MAibcTli4IisCtbHKrGMh
#
#                                     title  \
# 0                                  Butter
# 1                                good 4 u
# 2               Levitating (feat. DaBaby)
# 3  Peaches (feat. Daniel Caesar & Giveon)
# 4                     Leave The Door Open
#
#                                   artists
# 0                                     BTS
# 1                          Olivia Rodrigo
# 2                        Dua Lipa, DaBaby
# 3    Justin Bieber, Daniel Caesar, Giveon
# 4  Bruno Mars, Anderson .Paak, Silk Sonic
#
# [5 rows x 21 columns]

# %%
hot_extra_features.columns
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms',
#        'time_signature', 'SongId', 'title', 'artists'],
#       dtype='object')

# %% [markdown]
# ### 2.4. Merging audio features with previous DF for Hot Songs

# %%
hot_songs_df= hot_songs.join(hot_extra_features.iloc[:,:-2]) 
# In the hot_extra_features data frame, the info of th last columns is repeated 
#(title and artist), so I will just sliced the
hot_songs_df.head(10)
# Out:
#                     title                                          artist  \
# 0                  Butter                                             BTS
# 1                Good 4 U                                  Olivia Rodrigo
# 2              Levitating                       Dua Lipa Featuring DaBaby
# 3                 Peaches  Justin Bieber Featuring Daniel Caesar & Giveon
# 4     Leave The Door Open        Silk Sonic (Bruno Mars & Anderson .Paak)
# 5         Save Your Tears                      The Weeknd & Ariana Grande
# 6            Kiss Me More                          Doja Cat Featuring SZA
# 7  Astronaut In The Ocean                                     Masked Wolf
# 8                 Deja Vu                                  Olivia Rodrigo
# 9                Yonaguni                                       Bad Bunny
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.759   0.459    8    -5.187     1       0.0948       0.00323
# 1         0.556   0.661    6    -5.052     0       0.2040       0.30000
# 2         0.702   0.825    6    -3.787     0       0.0601       0.00883
# 3         0.677   0.696    0    -6.181     1       0.1190       0.32100
# 4         0.586   0.616    5    -7.964     1       0.0324       0.18200
# 5         0.650   0.825    0    -4.645     1       0.0325       0.02150
# 6         0.762   0.701    8    -3.541     1       0.0286       0.23500
# 7         0.778   0.695    4    -6.865     0       0.0913       0.17500
# 8         0.442   0.612    2    -7.222     1       0.1120       0.58400
# 9         0.644   0.648    1    -4.601     1       0.1180       0.27600
#
#    instrumentalness  ...  valence    tempo            type  \
# 0          0.000000  ...    0.695  109.997  audio_features
# 1          0.000000  ...    0.668  168.560  audio_features
# 2          0.000000  ...    0.915  102.977  audio_features
# 3          0.000000  ...    0.464   90.030  audio_features
# 4          0.000000  ...    0.719  148.088  audio_features
# 5          0.000024  ...    0.593  118.091  audio_features
# 6          0.000158  ...    0.742  110.968  audio_features
# 7          0.000000  ...    0.472  149.996  audio_features
# 8          0.000006  ...    0.178  180.917  audio_features
# 9          0.000000  ...    0.440  179.951  audio_features
#
#                        id                                   uri  \
# 0  2bgTY4UwhfBYhGT4HUYStN  spotify:track:2bgTY4UwhfBYhGT4HUYStN
# 1  6PERP62TejQjgHu81OHxgM  spotify:track:6PERP62TejQjgHu81OHxgM
# 2  463CkQjx2Zk1yXoBuierM9  spotify:track:463CkQjx2Zk1yXoBuierM9
# 3  4iJyoBOLtHqaGxP12qzhQI  spotify:track:4iJyoBOLtHqaGxP12qzhQI
# 4  7MAibcTli4IisCtbHKrGMh  spotify:track:7MAibcTli4IisCtbHKrGMh
# 5  37BZB0z9T8Xu7U3e65qxFy  spotify:track:37BZB0z9T8Xu7U3e65qxFy
# 6  748mdHapucXQri7IAO8yFK  spotify:track:748mdHapucXQri7IAO8yFK
# 7  3Ofmpyhv5UAQ70mENzB277  spotify:track:3Ofmpyhv5UAQ70mENzB277
# 8  6HU7h9RYOaPRFeh0R3UeAr  spotify:track:6HU7h9RYOaPRFeh0R3UeAr
# 9  2JPLbjOn0wPCngEot2STUS  spotify:track:2JPLbjOn0wPCngEot2STUS
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/2bgTY4UwhfBY...
# 1  https://api.spotify.com/v1/tracks/6PERP62TejQj...
# 2  https://api.spotify.com/v1/tracks/463CkQjx2Zk1...
# 3  https://api.spotify.com/v1/tracks/4iJyoBOLtHqa...
# 4  https://api.spotify.com/v1/tracks/7MAibcTli4Ii...
# 5  https://api.spotify.com/v1/tracks/37BZB0z9T8Xu...
# 6  https://api.spotify.com/v1/tracks/748mdHapucXQ...
# 7  https://api.spotify.com/v1/tracks/3Ofmpyhv5UAQ...
# 8  https://api.spotify.com/v1/tracks/6HU7h9RYOaPR...
# 9  https://api.spotify.com/v1/tracks/2JPLbjOn0wPC...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/2bgT...      164442
# 1  https://api.spotify.com/v1/audio-analysis/6PER...      178148
# 2  https://api.spotify.com/v1/audio-analysis/463C...      203064
# 3  https://api.spotify.com/v1/audio-analysis/4iJy...      198082
# 4  https://api.spotify.com/v1/audio-analysis/7MAi...      242096
# 5  https://api.spotify.com/v1/audio-analysis/37BZ...      191014
# 6  https://api.spotify.com/v1/audio-analysis/748m...      208867
# 7  https://api.spotify.com/v1/audio-analysis/3Ofm...      132780
# 8  https://api.spotify.com/v1/audio-analysis/6HU7...      215507
# 9  https://api.spotify.com/v1/audio-analysis/2JPL...      206710
#
#    time_signature                  SongId
# 0               4  2bgTY4UwhfBYhGT4HUYStN
# 1               4  6PERP62TejQjgHu81OHxgM
# 2               4  463CkQjx2Zk1yXoBuierM9
# 3               4  4iJyoBOLtHqaGxP12qzhQI
# 4               4  7MAibcTli4IisCtbHKrGMh
# 5               4  37BZB0z9T8Xu7U3e65qxFy
# 6               4  748mdHapucXQri7IAO8yFK
# 7               4  3Ofmpyhv5UAQ70mENzB277
# 8               4  6HU7h9RYOaPRFeh0R3UeAr
# 9               4  2JPLbjOn0wPCngEot2STUS
#
# [10 rows x 21 columns]

# %%
hot_songs_df.columns
# Out:
# Index(['title', 'artist', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'type', 'id', 'uri', 'track_href', 'analysis_url',
#        'duration_ms', 'time_signature', 'SongId'],
#       dtype='object')

# %%
#drop extra and repeated columns
hot_songs_df=hot_songs_df.drop(columns=["type","time_signature","analysis_url","track_href","SongId"])

# %%
hot_songs_df.tail(10)
# Out:
#                                 title                          artist  \
# 90                  Chasing After You     Ryan Hurd With Maren Morris
# 91                            Tell Em                  Cochise & $NOT
# 92                          4 Da Gang           42 Dugg & Roddy Ricch
# 93                          Tombstone                        Rod Wave
# 94                        What's Next                           Drake
# 95           Things A Man Oughta Know                   Lainey Wilson
# 96                      Country Again                    Thomas Rhett
# 97  Drunk (And I Don't Wanna Go Home)     Elle King & Miranda Lambert
# 98                     If You Want To             Lil Baby & Lil Durk
# 99                       Seeing Green  Nicki Minaj, Drake & Lil Wayne
#
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 90         0.596   0.679    4    -6.395     1       0.0394       0.72300
# 91         0.672   0.717    5    -7.476     1       0.2260       0.10300
# 92         0.871   0.545    7   -10.489     1       0.1890       0.01430
# 93         0.550   0.637    8    -5.212     1       0.1630       0.59700
# 94         0.777   0.580    0    -6.928     0       0.0525       0.01250
# 95         0.659   0.683    3    -5.623     1       0.0312       0.51300
# 96         0.467   0.481    2    -6.947     1       0.0255       0.22700
# 97         0.612   0.884    5    -4.400     1       0.0459       0.00516
# 98         0.795   0.599    6    -7.819     1       0.1230       0.04140
# 99         0.573   0.867    5    -2.876     0       0.1680       0.08530
#
#     instrumentalness  liveness  valence    tempo                      id  \
# 90          0.000000    0.1160   0.4790  131.912  1ZIKpMTRPqhwAoVXWY3tXI
# 91          0.000000    0.3980   0.4730  157.905  7nc7mlSdWYeFom84zZ8Wr8
# 92          0.000000    0.1480   0.7220  100.482  4KIkADzoVm3A10E9qyjsQ5
# 93          0.000000    0.1290   0.5350   84.448  5pRTz4O2qOkr5nawemy6Wb
# 94          0.000000    0.1610   0.0636  129.918  3mDFLytDotXo2p0rvfGbkA
# 95          0.000005    0.1330   0.3970  139.931  5QS8PNEWbqTEZyQ6e9ZbJf
# 96          0.000189    0.1100   0.2480  147.886  3CiF9D8iuVhZWDvvjf8HpG
# 97          0.000000    0.0997   0.6260  119.991  0QULNNd9z5s35entfiiXoa
# 98          0.000000    0.1930   0.3510   97.033  1EXRmdtTA2IEnYGiuw9plD
# 99          0.000000    0.3800   0.2310   74.861  1TZv3bujNaYz646eezRE91
#
#                                      uri  duration_ms
# 90  spotify:track:1ZIKpMTRPqhwAoVXWY3tXI       207974
# 91  spotify:track:7nc7mlSdWYeFom84zZ8Wr8       180380
# 92  spotify:track:4KIkADzoVm3A10E9qyjsQ5       155720
# 93  spotify:track:5pRTz4O2qOkr5nawemy6Wb       160078
# 94  spotify:track:3mDFLytDotXo2p0rvfGbkA       178154
# 95  spotify:track:5QS8PNEWbqTEZyQ6e9ZbJf       203373
# 96  spotify:track:3CiF9D8iuVhZWDvvjf8HpG       221240
# 97  spotify:track:0QULNNd9z5s35entfiiXoa       245626
# 98  spotify:track:1EXRmdtTA2IEnYGiuw9plD       195454
# 99  spotify:track:1TZv3bujNaYz646eezRE91       339506

# %%
#test: hot_songs_df.to_csv("../../db_hot.csv")

# %% [markdown]
# ## 3. Spotify: Create DB

# %% [markdown]
# We want to create a df with arouns 10.000 song with following info:
# - title
# - artist
# - all the audio features

# %% [markdown]
# ### 3.1. Retrive tracks from playlist

# %%
from time import sleep
from random import randint
import re

# %%
def get_ids_playlists_from_txt(path_file):
    '''
    This function will open a txt file with the link of all the playslits, retrive the playlist ID.
    Output: list with all the playlists ID's
    '''
    f = open(path_file)
    playlists = f.read()
    playlists = playlists.split("\n")
    playlists = [re.findall(r"\/(\d.*)\?",playlist) for playlist in playlists]
    playlists = [elem[0] for elem in playlists]
    return playlists

# %%
playlists = get_ids_playlists_from_txt("../data/playlists.txt")

# %%
len(playlists)
# Out:
# 44

# %%
def get_playlist_tracks(username, playlist_id):
    '''
    This function will allow us to get the tracks from one playlist and navigate thought all the pages, as
    otherwise, it will be just able to retrieve information from one of the pages (every pages has a limit of songs)
    Output = All the information from the tracks in a playlist
    '''
    results = sp.user_playlist_tracks(username,playlist_id)
    tracks = results['items'] #list, and we will extend this list
    while results['next']: #while I have a next
        results = sp.next(results)
        seconds_to_wait = randint(2,7)
        sleep(seconds_to_wait)
        tracks.extend(results['items']) #extend my list to the results before. items
    return tracks

# %%
def parse_all_info_playlists(playlist_list):
    '''
    This function will allow us to make a big list with all the information from all the tracks from all playlists.
    Input: list of playlist ID's
    Output: A list with all tracks information
    '''
    all_results=[]
    for playlist in playlist_list:
        results =get_playlist_tracks("spotify",playlist)
        all_results.extend(results)
        
    return all_results

# %%
all_info_tracks = parse_all_info_playlists(playlists)

# %%
def get_info_from_the_tracks_from_parsed_info_playlist(tracks):
    '''
    Once we have parsed all information  we can use this function to get a list of id's, artist name and
    song name of each track in the playlist.
    '''
    name_list= []
    id_list = []
    artist_list = []

    for item in tracks:#results["items"]: #iterate over this, each song entry
        track_name = item["track"]["name"] #nombre de la cancion
        track_id = item["track"]["id"] #id de la cancion
        track_artist = item["track"]["artists"][0]["name"]
        name_list.append(track_name)
        id_list.append(track_id)
        artist_list.append(track_artist)
    return name_list,id_list,artist_list

# %%
title_spoty,id_spoty,artist_spoty = get_info_from_the_tracks_from_parsed_info_playlist(all_info_tracks)

# %%
tracks_spoty=pd.DataFrame({"title":title_spoty,"Id":id_spoty,"artist":artist_spoty})
tracks_spoty.tail()
# Out:
#                                       title                      Id  \
# 10671                       Hermit the Frog  4Zcz6saEkOII3PlXd9gN3o
# 10672                               deja vu  61KpQadow081I2AsbeLcsb
# 10673                     WHOLE LOTTA MONEY  5yorXJWdBan1Vlh116ZtQ7
# 10674  Slumber Party (feat. Princess Nokia)  11ZulcYY4lowvcQm4oe3VJ
# 10675                             telepatía  6tDDoYIxWvMLTdKpjFkc1B
#
#                artist
# 10671          MARINA
# 10672  Olivia Rodrigo
# 10673             BIA
# 10674        Ashnikko
# 10675      Kali Uchis

# %%
len(tracks_spoty)
# tracks_spoty.iloc[1960:1980,:]
# Out:
# 10676

# %%
tracks_spoty.isna().sum()
# Out:
# title     0
# Id        2
# artist    0
# dtype: int64

# %% [markdown]
# ### 3.2. Get audio features for playlist

# %% [markdown]
# We can just get 100 in every query, so we are gonna have to itereate every 100 ids and give a new 100 ids again.

# %%
def chunks(lst, n):
    """Yield successive n-sized chunks from lst."""
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

# %%
#i get my chunks of 100 songs

id_spotify_chunk_100 = list(chunks(id_spoty, 100))
len(id_spotify_chunk_100)
# Out:
# 107

# %%
#I need to change those two values as the id was not retrieve, it gives None, and then gives 
#an error when we try to get the audio features
id_spotify_chunk_100[19][68] ='0yfNXxlyXdmP0ue1iJijx1' 
id_spotify_chunk_100[19][67] ='0yfNXxlyXdmP0ue1iJijx1'
#Afterward I will delete this songs form the data set, but I need to keep them to mantain the order for the
#next step that is to get the audio features

# %%
def get_audio_features_from_id(id_chunks_of_100):
    '''
    This function takes chunks of 100 id's from the tracks and retruns the audio features in 
    '''
    first=True
    for chunk in id_chunks_of_100:
        audio_features_spoty= sp.audio_features(tracks=chunk)
        if first:
            all_features = audio_features_spoty
            first = False
        else:
            all_features.extend(audio_features_spoty)
    return all_features

# %%
all_features = get_audio_features_from_id(id_spotify_chunk_100)

# %%
len(all_features)
# Out:
# 10676

# %%
#I get an error :AttributeError: 'NoneType' object has no attribute 'keys') when I try to create the dataframe.

#As I am not able to fix the problem without losing the order...
#I found the elements that are non type, I will try to change them with a the same dictionary and NaN values (np.nan)
#otherwise does not fix it
#all_features[4589], 4689,4690 5360 are the ones, 4694,5365

# %%
type(all_features[4589])
# Out:
# dict

# %%
all_features[4589]= {'danceability': np.nan,'energy': np.nan,'key': np.nan,'loudness': np.nan,'mode': np.nan,
                     'speechiness': np.nan,'acousticness': np.nan,'instrumentalness': np.nan,'liveness': np.nan,
                     'valence': np.nan,'tempo': np.nan,'type': np.nan,'id': np.nan,'uri': np.nan,
                     'track_href': np.nan,'analysis_url': np.nan,'duration_ms': np.nan,'time_signature': np.nan}

# %%
all_features[4689]= {'danceability': np.nan,'energy': np.nan,'key': np.nan,'loudness': np.nan,'mode': np.nan,
                     'speechiness': np.nan,'acousticness': np.nan,'instrumentalness': np.nan,'liveness': np.nan,
                     'valence': np.nan,'tempo': np.nan,'type': np.nan,'id': np.nan,'uri': np.nan,
                     'track_href': np.nan,'analysis_url': np.nan,'duration_ms': np.nan,'time_signature': np.nan}

# %%
all_features[5360]= {'danceability': np.nan,'energy': np.nan,'key': np.nan,'loudness': np.nan,'mode': np.nan,
                     'speechiness': np.nan,'acousticness': np.nan,'instrumentalness': np.nan,'liveness': np.nan,
                     'valence': np.nan,'tempo': np.nan,'type': np.nan,'id': np.nan,'uri': np.nan,
                     'track_href': np.nan,'analysis_url': np.nan,'duration_ms': np.nan,'time_signature': np.nan}

# %%
all_features[4590] = {'danceability': np.nan,'energy': np.nan,'key': np.nan,'loudness': np.nan,'mode': np.nan,
                     'speechiness': np.nan,'acousticness': np.nan,'instrumentalness': np.nan,'liveness': np.nan,
                     'valence': np.nan,'tempo': np.nan,'type': np.nan,'id': np.nan,'uri': np.nan,
                     'track_href': np.nan,'analysis_url': np.nan,'duration_ms': np.nan,'time_signature': np.nan}

# %%
all_features[4694]={'danceability': np.nan,'energy': np.nan,'key': np.nan,'loudness': np.nan,'mode': np.nan,
                     'speechiness': np.nan,'acousticness': np.nan,'instrumentalness': np.nan,'liveness': np.nan,
                     'valence': np.nan,'tempo': np.nan,'type': np.nan,'id': np.nan,'uri': np.nan,
                     'track_href': np.nan,'analysis_url': np.nan,'duration_ms': np.nan,'time_signature': np.nan}

# %%
all_features[5365]={'danceability': np.nan,'energy': np.nan,'key': np.nan,'loudness': np.nan,'mode': np.nan,
                     'speechiness': np.nan,'acousticness': np.nan,'instrumentalness': np.nan,'liveness': np.nan,
                     'valence': np.nan,'tempo': np.nan,'type': np.nan,'id': np.nan,'uri': np.nan,
                     'track_href': np.nan,'analysis_url': np.nan,'duration_ms': np.nan,'time_signature': np.nan}

# %%
pd.DataFrame(all_features[5365:])
# Out:
#       danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0              NaN     NaN   NaN       NaN   NaN          NaN           NaN
# 1            0.395   0.375   0.0    -7.948   1.0       0.0340       0.22500
# 2            0.289   0.167   0.0   -12.991   1.0       0.0394       0.93100
# 3            0.788   0.745   5.0    -7.072   1.0       0.2580       0.29000
# 4            0.512   0.499   0.0    -6.485   1.0       0.0519       0.80900
# ...            ...     ...   ...       ...   ...          ...           ...
# 5306         0.609   0.679   0.0    -4.545   1.0       0.0312       0.24300
# 5307         0.439   0.610   9.0    -7.236   1.0       0.1160       0.59300
# 5308         0.897   0.371   1.0    -5.019   1.0       0.3680       0.09040
# 5309         0.964   0.398  11.0    -8.981   0.0       0.0795       0.00151
# 5310         0.653   0.524  11.0    -9.016   0.0       0.0502       0.11200
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0                  NaN       NaN      NaN      NaN             NaN
# 1             0.000000    0.1450    0.131  121.040  audio_features
# 2             0.000001    0.1350    0.210  177.698  audio_features
# 3             0.000000    0.0373    0.672  135.278  audio_features
# 4             0.000022    0.2840    0.510   78.907  audio_features
# ...                ...       ...      ...      ...             ...
# 5306          0.000000    0.1990    0.487  122.034  audio_features
# 5307          0.000011    0.3410    0.172  181.088  audio_features
# 5308          0.000000    0.3250    0.441   81.008  audio_features
# 5309          0.000039    0.1010    0.563  105.012  audio_features
# 5310          0.000000    0.2030    0.553   83.970  audio_features
#
#                           id                                   uri  \
# 0                        NaN                                   NaN
# 1     5viFjDGTnrApmUY5c8qkfw  spotify:track:5viFjDGTnrApmUY5c8qkfw
# 2     5ysC9Ns62qa2NG8aty8lON  spotify:track:5ysC9Ns62qa2NG8aty8lON
# 3     6U4VqEHy4n5VeiH4pQPL24  spotify:track:6U4VqEHy4n5VeiH4pQPL24
# 4     2dlxN435ZY9ruxGYND2Hq0  spotify:track:2dlxN435ZY9ruxGYND2Hq0
# ...                      ...                                   ...
# 5306  4Zcz6saEkOII3PlXd9gN3o  spotify:track:4Zcz6saEkOII3PlXd9gN3o
# 5307  61KpQadow081I2AsbeLcsb  spotify:track:61KpQadow081I2AsbeLcsb
# 5308  5yorXJWdBan1Vlh116ZtQ7  spotify:track:5yorXJWdBan1Vlh116ZtQ7
# 5309  11ZulcYY4lowvcQm4oe3VJ  spotify:track:11ZulcYY4lowvcQm4oe3VJ
# 5310  6tDDoYIxWvMLTdKpjFkc1B  spotify:track:6tDDoYIxWvMLTdKpjFkc1B
#
#                                              track_href  \
# 0                                                   NaN
# 1     https://api.spotify.com/v1/tracks/5viFjDGTnrAp...
# 2     https://api.spotify.com/v1/tracks/5ysC9Ns62qa2...
# 3     https://api.spotify.com/v1/tracks/6U4VqEHy4n5V...
# 4     https://api.spotify.com/v1/tracks/2dlxN435ZY9r...
# ...                                                 ...
# 5306  https://api.spotify.com/v1/tracks/4Zcz6saEkOII...
# 5307  https://api.spotify.com/v1/tracks/61KpQadow081...
# 5308  https://api.spotify.com/v1/tracks/5yorXJWdBan1...
# 5309  https://api.spotify.com/v1/tracks/11ZulcYY4low...
# 5310  https://api.spotify.com/v1/tracks/6tDDoYIxWvML...
#
#                                            analysis_url  duration_ms  \
# 0                                                   NaN          NaN
# 1     https://api.spotify.com/v1/audio-analysis/5viF...     175594.0
# 2     https://api.spotify.com/v1/audio-analysis/5ysC...     156400.0
# 3     https://api.spotify.com/v1/audio-analysis/6U4V...     163893.0
# 4     https://api.spotify.com/v1/audio-analysis/2dlx...     144427.0
# ...                                                 ...          ...
# 5306  https://api.spotify.com/v1/audio-analysis/4Zcz...     215960.0
# 5307  https://api.spotify.com/v1/audio-analysis/61Kp...     215508.0
# 5308  https://api.spotify.com/v1/audio-analysis/5yor...     156005.0
# 5309  https://api.spotify.com/v1/audio-analysis/11Zu...     178405.0
# 5310  https://api.spotify.com/v1/audio-analysis/6tDD...     160191.0
#
#       time_signature
# 0                NaN
# 1                4.0
# 2                4.0
# 3                4.0
# 4                4.0
# ...              ...
# 5306             4.0
# 5307             4.0
# 5308             4.0
# 5309             4.0
# 5310             4.0
#
# [5311 rows x 18 columns]

# %%
features_spoty= pd.DataFrame(all_features)
features_spoty.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0        0.2210  0.1260  0.0   -25.427   1.0       0.0447         0.989
# 1        0.0811  0.0122  4.0   -32.654   0.0       0.0511         0.902
# 2        0.0939  0.0336  2.0   -24.041   0.0       0.0606         0.927
# 3        0.2300  0.0487  5.0   -27.675   1.0       0.0412         0.986
# 4        0.2050  0.0525  1.0   -23.841   1.0       0.0327         0.980
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0             0.897    0.1020   0.2160  133.630  audio_features
# 1             0.308    0.0648   0.0384   74.554  audio_features
# 2             0.830    0.0954   0.0516   67.359  audio_features
# 3             0.945    0.0679   0.1010  134.839  audio_features
# 4             0.906    0.1030   0.0511   88.316  audio_features
#
#                        id                                   uri  \
# 0  4SFBV7SRNG2e2kyL1F6kjU  spotify:track:4SFBV7SRNG2e2kyL1F6kjU
# 1  2kAgCRZPG3YQR2VMqRvLmb  spotify:track:2kAgCRZPG3YQR2VMqRvLmb
# 2  1upQiytDIEZfl9ItruoXuC  spotify:track:1upQiytDIEZfl9ItruoXuC
# 3  0H2VhGUC3P3hvwz8rdGIpC  spotify:track:0H2VhGUC3P3hvwz8rdGIpC
# 4  419qlOGNXoyICx4jO0hqaj  spotify:track:419qlOGNXoyICx4jO0hqaj
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/4SFBV7SRNG2e...
# 1  https://api.spotify.com/v1/tracks/2kAgCRZPG3YQ...
# 2  https://api.spotify.com/v1/tracks/1upQiytDIEZf...
# 3  https://api.spotify.com/v1/tracks/0H2VhGUC3P3h...
# 4  https://api.spotify.com/v1/tracks/419qlOGNXoyI...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/4SFB...     139307.0
# 1  https://api.spotify.com/v1/audio-analysis/2kAg...     935360.0
# 2  https://api.spotify.com/v1/audio-analysis/1upQ...     207267.0
# 3  https://api.spotify.com/v1/audio-analysis/0H2V...     203656.0
# 4  https://api.spotify.com/v1/audio-analysis/419q...     174653.0
#
#    time_signature
# 0             4.0
# 1             4.0
# 2             3.0
# 3             5.0
# 4             4.0

# %% [markdown]
# ### 3.3. Put all together

# %%
tracks_spoty =tracks_spoty.reset_index(drop=True)

# %%
features_spoty = features_spoty.reset_index(drop=True)

# %%
display(tracks_spoty.tail()) 
display(features_spoty.tail())
# Out:
#                                       title                      Id  \
# 10671                       Hermit the Frog  4Zcz6saEkOII3PlXd9gN3o
# 10672                               deja vu  61KpQadow081I2AsbeLcsb
# 10673                     WHOLE LOTTA MONEY  5yorXJWdBan1Vlh116ZtQ7
# 10674  Slumber Party (feat. Princess Nokia)  11ZulcYY4lowvcQm4oe3VJ
# 10675                             telepatía  6tDDoYIxWvMLTdKpjFkc1B
#
#                artist
# 10671          MARINA
# 10672  Olivia Rodrigo
# 10673             BIA
# 10674        Ashnikko
# 10675      Kali Uchis
#        danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 10671         0.609   0.679   0.0    -4.545   1.0       0.0312       0.24300
# 10672         0.439   0.610   9.0    -7.236   1.0       0.1160       0.59300
# 10673         0.897   0.371   1.0    -5.019   1.0       0.3680       0.09040
# 10674         0.964   0.398  11.0    -8.981   0.0       0.0795       0.00151
# 10675         0.653   0.524  11.0    -9.016   0.0       0.0502       0.11200
#
#        instrumentalness  liveness  valence    tempo            type  \
# 10671          0.000000     0.199    0.487  122.034  audio_features
# 10672          0.000011     0.341    0.172  181.088  audio_features
# 10673          0.000000     0.325    0.441   81.008  audio_features
# 10674          0.000039     0.101    0.563  105.012  audio_features
# 10675          0.000000     0.203    0.553   83.970  audio_features
#
#                            id                                   uri  \
# 10671  4Zcz6saEkOII3PlXd9gN3o  spotify:track:4Zcz6saEkOII3PlXd9gN3o
# 10672  61KpQadow081I2AsbeLcsb  spotify:track:61KpQadow081I2AsbeLcsb
# 10673  5yorXJWdBan1Vlh116ZtQ7  spotify:track:5yorXJWdBan1Vlh116ZtQ7
# 10674  11ZulcYY4lowvcQm4oe3VJ  spotify:track:11ZulcYY4lowvcQm4oe3VJ
# 10675  6tDDoYIxWvMLTdKpjFkc1B  spotify:track:6tDDoYIxWvMLTdKpjFkc1B
#
#                                               track_href  \
# 10671  https://api.spotify.com/v1/tracks/4Zcz6saEkOII...
# 10672  https://api.spotify.com/v1/tracks/61KpQadow081...
# 10673  https://api.spotify.com/v1/tracks/5yorXJWdBan1...
# 10674  https://api.spotify.com/v1/tracks/11ZulcYY4low...
# 10675  https://api.spotify.com/v1/tracks/6tDDoYIxWvML...
#
#                                             analysis_url  duration_ms  \
# 10671  https://api.spotify.com/v1/audio-analysis/4Zcz...     215960.0
# 10672  https://api.spotify.com/v1/audio-analysis/61Kp...     215508.0
# 10673  https://api.spotify.com/v1/audio-analysis/5yor...     156005.0
# 10674  https://api.spotify.com/v1/audio-analysis/11Zu...     178405.0
# 10675  https://api.spotify.com/v1/audio-analysis/6tDD...     160191.0
#
#        time_signature
# 10671             4.0
# 10672             4.0
# 10673             4.0
# 10674             4.0
# 10675             4.0

# %%
spoty_df = tracks_spoty.join(features_spoty)
spoty_df.tail()
# Out:
#                                       title                      Id  \
# 10671                       Hermit the Frog  4Zcz6saEkOII3PlXd9gN3o
# 10672                               deja vu  61KpQadow081I2AsbeLcsb
# 10673                     WHOLE LOTTA MONEY  5yorXJWdBan1Vlh116ZtQ7
# 10674  Slumber Party (feat. Princess Nokia)  11ZulcYY4lowvcQm4oe3VJ
# 10675                             telepatía  6tDDoYIxWvMLTdKpjFkc1B
#
#                artist  danceability  energy   key  loudness  mode  \
# 10671          MARINA         0.609   0.679   0.0    -4.545   1.0
# 10672  Olivia Rodrigo         0.439   0.610   9.0    -7.236   1.0
# 10673             BIA         0.897   0.371   1.0    -5.019   1.0
# 10674        Ashnikko         0.964   0.398  11.0    -8.981   0.0
# 10675      Kali Uchis         0.653   0.524  11.0    -9.016   0.0
#
#        speechiness  acousticness  ...  liveness  valence    tempo  \
# 10671       0.0312       0.24300  ...     0.199    0.487  122.034
# 10672       0.1160       0.59300  ...     0.341    0.172  181.088
# 10673       0.3680       0.09040  ...     0.325    0.441   81.008
# 10674       0.0795       0.00151  ...     0.101    0.563  105.012
# 10675       0.0502       0.11200  ...     0.203    0.553   83.970
#
#                  type                      id  \
# 10671  audio_features  4Zcz6saEkOII3PlXd9gN3o
# 10672  audio_features  61KpQadow081I2AsbeLcsb
# 10673  audio_features  5yorXJWdBan1Vlh116ZtQ7
# 10674  audio_features  11ZulcYY4lowvcQm4oe3VJ
# 10675  audio_features  6tDDoYIxWvMLTdKpjFkc1B
#
#                                         uri  \
# 10671  spotify:track:4Zcz6saEkOII3PlXd9gN3o
# 10672  spotify:track:61KpQadow081I2AsbeLcsb
# 10673  spotify:track:5yorXJWdBan1Vlh116ZtQ7
# 10674  spotify:track:11ZulcYY4lowvcQm4oe3VJ
# 10675  spotify:track:6tDDoYIxWvMLTdKpjFkc1B
#
#                                               track_href  \
# 10671  https://api.spotify.com/v1/tracks/4Zcz6saEkOII...
# 10672  https://api.spotify.com/v1/tracks/61KpQadow081...
# 10673  https://api.spotify.com/v1/tracks/5yorXJWdBan1...
# 10674  https://api.spotify.com/v1/tracks/11ZulcYY4low...
# 10675  https://api.spotify.com/v1/tracks/6tDDoYIxWvML...
#
#                                             analysis_url duration_ms  \
# 10671  https://api.spotify.com/v1/audio-analysis/4Zcz...    215960.0
# 10672  https://api.spotify.com/v1/audio-analysis/61Kp...    215508.0
# 10673  https://api.spotify.com/v1/audio-analysis/5yor...    156005.0
# 10674  https://api.spotify.com/v1/audio-analysis/11Zu...    178405.0
# 10675  https://api.spotify.com/v1/audio-analysis/6tDD...    160191.0
#
#        time_signature
# 10671             4.0
# 10672             4.0
# 10673             4.0
# 10674             4.0
# 10675             4.0
#
# [5 rows x 21 columns]

# %%
spoty_df.columns
# Out:
# Index(['title', 'Id', 'artist', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'type', 'id', 'uri', 'track_href', 'analysis_url',
#        'duration_ms', 'time_signature'],
#       dtype='object')

# %%
#Drop extra columns

spoty_df =spoty_df.drop(columns=["type","time_signature","analysis_url","track_href","Id"])

# %%
#Arrange the columns in the same orther as the Hotsong DB and wiht same colum names

spoty_df = spoty_df.reindex(columns=['title', 'artist', 'danceability', 'energy', 'key', 'loudness', 'mode',
       'speechiness', 'acousticness', 'instrumentalness', 'liveness',
       'valence', 'tempo', 'id', 'uri', 'duration_ms'])

# %%
#I am gonna delete the rows with the NaN values:
is_NaN = spoty_df.isnull()
row_has_NaN = is_NaN.any(axis=1)
rows_with_NaN = spoty_df[row_has_NaN]
rows_with_NaN
# Out:
#                                                   title        artist  \
# 4589                    Losing My Religion (feat. MKLA)    Steve Aoki
# 4590             Memories (feat. Kid Cudi) - 2021 Remix  David Guetta
# 4689                                           Rasputin      Majestic
# 4694             Memories (feat. Kid Cudi) - 2021 Remix  David Guetta
# 5360  I've Got a Dream - From "Tangled"/Soundtrack V...   Mandy Moore
# 5365                         One Jump Ahead (Reprise 2)  Mena Massoud
#
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 4589           NaN     NaN  NaN       NaN   NaN          NaN           NaN
# 4590           NaN     NaN  NaN       NaN   NaN          NaN           NaN
# 4689           NaN     NaN  NaN       NaN   NaN          NaN           NaN
# 4694           NaN     NaN  NaN       NaN   NaN          NaN           NaN
# 5360           NaN     NaN  NaN       NaN   NaN          NaN           NaN
# 5365           NaN     NaN  NaN       NaN   NaN          NaN           NaN
#
#       instrumentalness  liveness  valence  tempo   id  uri  duration_ms
# 4589               NaN       NaN      NaN    NaN  NaN  NaN          NaN
# 4590               NaN       NaN      NaN    NaN  NaN  NaN          NaN
# 4689               NaN       NaN      NaN    NaN  NaN  NaN          NaN
# 4694               NaN       NaN      NaN    NaN  NaN  NaN          NaN
# 5360               NaN       NaN      NaN    NaN  NaN  NaN          NaN
# 5365               NaN       NaN      NaN    NaN  NaN  NaN          NaN

# %%
list(rows_with_NaN.index.values)
# Out:
# [4589, 4590, 4689, 4694, 5360, 5365]

# %%
#I will drop them:[4689,:],[5360,:]

spoty_df = spoty_df.drop(list(rows_with_NaN.index.values))

# %%
len(spoty_df)
# Out:
# 10670

# %%
#I will also drop duplicates:

spoty_df = spoty_df.drop_duplicates()

# %%
len(spoty_df) # Final size 10018
# Out:
# 10018

# %%
spoty_df.head()
# Out:
#                                                title                  artist  \
# 0  The Well-Tempered Clavier: Book 1, BWV 846-869...   Johann Sebastian Bach
# 1                                 The Lark Ascending  Ralph Vaughan Williams
# 2  Handel / Orch. Hale: Keyboard Suite in D Minor...  George Frideric Handel
# 3   Bagatelle No. 25 in A Minor, "Für Elise", WoO 59    Ludwig van Beethoven
# 4  Rhapsody On A Theme Of Paganini, Op.43: Variat...     Sergei Rachmaninoff
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0        0.2210  0.1260  0.0   -25.427   1.0       0.0447         0.989
# 1        0.0811  0.0122  4.0   -32.654   0.0       0.0511         0.902
# 2        0.0939  0.0336  2.0   -24.041   0.0       0.0606         0.927
# 3        0.2300  0.0487  5.0   -27.675   1.0       0.0412         0.986
# 4        0.2050  0.0525  1.0   -23.841   1.0       0.0327         0.980
#
#    instrumentalness  liveness  valence    tempo                      id  \
# 0             0.897    0.1020   0.2160  133.630  4SFBV7SRNG2e2kyL1F6kjU
# 1             0.308    0.0648   0.0384   74.554  2kAgCRZPG3YQR2VMqRvLmb
# 2             0.830    0.0954   0.0516   67.359  1upQiytDIEZfl9ItruoXuC
# 3             0.945    0.0679   0.1010  134.839  0H2VhGUC3P3hvwz8rdGIpC
# 4             0.906    0.1030   0.0511   88.316  419qlOGNXoyICx4jO0hqaj
#
#                                     uri  duration_ms
# 0  spotify:track:4SFBV7SRNG2e2kyL1F6kjU     139307.0
# 1  spotify:track:2kAgCRZPG3YQR2VMqRvLmb     935360.0
# 2  spotify:track:1upQiytDIEZfl9ItruoXuC     207267.0
# 3  spotify:track:0H2VhGUC3P3hvwz8rdGIpC     203656.0
# 4  spotify:track:419qlOGNXoyICx4jO0hqaj     174653.0

# %%
spoty_df.to_csv("../../db_spotify.csv")

# %% [markdown]
# ## 3. PUT BOTH DB TOGETHER FOR K-MEANS AND GET LABELS

# %%
# hot_songs_df = pd.read_csv("../../db_hot.csv")

# %%
# spoty_df = pd.read_csv("../../db_spotify.csv")

# %% [markdown]
# ### 3.1. Concatenate data frames

# %%
all_df = pd.concat([hot_songs_df, spoty_df], axis=0)

# %%
all_df.shape
# Out:
# (10118, 17)

# %%
all_df = all_df.reset_index()

# %%
all_df = all_df.iloc[:,1:]

# %%
all_df
# Out:
#                                       title  \
# 0                                    Butter
# 1                                  Good 4 U
# 2                                Levitating
# 3                                   Peaches
# 4                       Leave The Door Open
# ...                                     ...
# 10113                                Freaks
# 10114                       Hermit the Frog
# 10115                     WHOLE LOTTA MONEY
# 10116  Slumber Party (feat. Princess Nokia)
# 10117                             telepatía
#
#                                                artist  danceability  energy  \
# 0                                                 BTS         0.759   0.459
# 1                                      Olivia Rodrigo         0.556   0.661
# 2                           Dua Lipa Featuring DaBaby         0.702   0.825
# 3      Justin Bieber Featuring Daniel Caesar & Giveon         0.677   0.696
# 4            Silk Sonic (Bruno Mars & Anderson .Paak)         0.586   0.616
# ...                                               ...           ...     ...
# 10113                                      Surf Curse         0.346   0.944
# 10114                                          MARINA         0.609   0.679
# 10115                                             BIA         0.897   0.371
# 10116                                        Ashnikko         0.964   0.398
# 10117                                      Kali Uchis         0.653   0.524
#
#         key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0       8.0    -5.187   1.0       0.0948      0.003230          0.000000
# 1       6.0    -5.052   0.0       0.2040      0.300000          0.000000
# 2       6.0    -3.787   0.0       0.0601      0.008830          0.000000
# 3       0.0    -6.181   1.0       0.1190      0.321000          0.000000
# 4       5.0    -7.964   1.0       0.0324      0.182000          0.000000
# ...     ...       ...   ...          ...           ...               ...
# 10113   9.0    -9.874   1.0       0.0485      0.000042          0.565000
# 10114   0.0    -4.545   1.0       0.0312      0.243000          0.000000
# 10115   1.0    -5.019   1.0       0.3680      0.090400          0.000000
# 10116  11.0    -8.981   0.0       0.0795      0.001510          0.000039
# 10117  11.0    -9.016   0.0       0.0502      0.112000          0.000000
#
#        liveness  valence    tempo                      id  \
# 0        0.0906    0.695  109.997  2bgTY4UwhfBYhGT4HUYStN
# 1        0.1010    0.668  168.560  6PERP62TejQjgHu81OHxgM
# 2        0.0674    0.915  102.977  463CkQjx2Zk1yXoBuierM9
# 3        0.4200    0.464   90.030  4iJyoBOLtHqaGxP12qzhQI
# 4        0.0927    0.719  148.088  7MAibcTli4IisCtbHKrGMh
# ...         ...      ...      ...                     ...
# 10113    0.0546    0.403  179.630  0HUTL8i4y4MiGCPId7M7wb
# 10114    0.1990    0.487  122.034  4Zcz6saEkOII3PlXd9gN3o
# 10115    0.3250    0.441   81.008  5yorXJWdBan1Vlh116ZtQ7
# 10116    0.1010    0.563  105.012  11ZulcYY4lowvcQm4oe3VJ
# 10117    0.2030    0.553   83.970  6tDDoYIxWvMLTdKpjFkc1B
#
#                                         uri  duration_ms  category
# 0      spotify:track:2bgTY4UwhfBYhGT4HUYStN     164442.0       0.0
# 1      spotify:track:6PERP62TejQjgHu81OHxgM     178148.0       2.0
# 2      spotify:track:463CkQjx2Zk1yXoBuierM9     203064.0       2.0
# 3      spotify:track:4iJyoBOLtHqaGxP12qzhQI     198082.0       4.0
# 4      spotify:track:7MAibcTli4IisCtbHKrGMh     242096.0       0.0
# ...                                     ...          ...       ...
# 10113  spotify:track:0HUTL8i4y4MiGCPId7M7wb     147036.0       NaN
# 10114  spotify:track:4Zcz6saEkOII3PlXd9gN3o     215960.0       NaN
# 10115  spotify:track:5yorXJWdBan1Vlh116ZtQ7     156005.0       NaN
# 10116  spotify:track:11ZulcYY4lowvcQm4oe3VJ     178405.0       NaN
# 10117  spotify:track:6tDDoYIxWvMLTdKpjFkc1B     160191.0       NaN
#
# [10118 rows x 17 columns]

# %%
# # test
# all_df.to_csv("../../all_db.csv")

# %% [markdown]
# ### 5.2 Select the audio features interested (train model in another file)

# %%
all_features_4_cluster =all_df[['danceability', 'energy', 'key', 'loudness', 'mode','speechiness', 'acousticness', 'instrumentalness', 'liveness','valence', 'tempo']]

# %%
all_features_4_cluster.tail()
# Out:
#        danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 10113         0.346   0.944   9.0    -9.874   1.0       0.0485      0.000042
# 10114         0.609   0.679   0.0    -4.545   1.0       0.0312      0.243000
# 10115         0.897   0.371   1.0    -5.019   1.0       0.3680      0.090400
# 10116         0.964   0.398  11.0    -8.981   0.0       0.0795      0.001510
# 10117         0.653   0.524  11.0    -9.016   0.0       0.0502      0.112000
#
#        instrumentalness  liveness  valence    tempo
# 10113          0.565000    0.0546    0.403  179.630
# 10114          0.000000    0.1990    0.487  122.034
# 10115          0.000000    0.3250    0.441   81.008
# 10116          0.000039    0.1010    0.563  105.012
# 10117          0.000000    0.2030    0.553   83.970

# %%
###export the file

all_features_4_cluster.to_csv("../data/audio_features_for_cluster.csv")
#continue working in other file

# %%
### Now I must go to the File, Scaling and training

# %% [markdown]
# ### 4.4 Add labels and export each DB

# %%
#retrieve scaled table of the audio features with an additional colums for groups
audio_features_for_cluster_labeled = pd.read_csv("../data/audio_features_for_cluster_labeled.csv",index_col=False)
audio_features_for_cluster_labeled.shape
# Out:
# (10118, 13)

# %%
audio_features_for_cluster_labeled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10118 entries, 0 to 10117
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        10118 non-null  int64
#  1   danceability      10118 non-null  float64
#  2   energy            10118 non-null  float64
#  3   key               10118 non-null  float64
#  4   loudness          10118 non-null  float64
#  5   mode              10118 non-null  float64
#  6   speechiness       10118 non-null  float64
#  7   acousticness      10118 non-null  float64
#  8   instrumentalness  10118 non-null  float64
#  9   liveness          10118 non-null  float64
#  10  valence           10118 non-null  float64
#  11  tempo             10118 non-null  float64
#  12  cluster           10118 non-null  int64
# dtypes: float64(11), int64(2)
# memory usage: 1.0 MB

# %%
#a bit annoying it appears a new column all the time
#Store column caterogry in labels to add it to the
labels = audio_features_for_cluster_labeled.iloc[:,-1]

# %%
labels.isnull().value_counts()
# Out:
# False    10118
# Name: cluster, dtype: int64

# %%
#Add labels column to the db
all_df["category"] = labels

# %%
all_df.info() #its seems ok the 100 first, that were the HoT100
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10118 entries, 0 to 10117
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        10118 non-null  int64
#  1   title             10115 non-null  object
#  2   artist            10113 non-null  object
#  3   danceability      10118 non-null  float64
#  4   energy            10118 non-null  float64
#  5   key               10118 non-null  float64
#  6   loudness          10118 non-null  float64
#  7   mode              10118 non-null  float64
#  8   speechiness       10118 non-null  float64
#  9   acousticness      10118 non-null  float64
#  10  instrumentalness  10118 non-null  float64
#  11  liveness          10118 non-null  float64
#  12  valence           10118 non-null  float64
#  13  tempo             10118 non-null  float64
#  14  id                10118 non-null  object
#  15  uri               10118 non-null  object
#  16  duration_ms       10118 non-null  float64
#  17  category          10118 non-null  int64
# dtypes: float64(12), int64(2), object(4)
# memory usage: 1.4+ MB

# %%
all_df['category'].value_counts()
# Out:
# 0    3714
# 2    2748
# 5    1472
# 1     944
# 4     567
# 6     344
# 3     329
# Name: category, dtype: int64

# %%
all_df = all_df.iloc[:,1:]

# %%
#Obtain our original HotSong DF with labels
hot_songs_df= all_df.iloc[:100,:]

# %%
#Obtain our original Spoty DF with labels
spoty_df = all_df.iloc[100:,:]

# %%
is_NaN = spoty_df.isnull()
row_has_NaN = is_NaN.any(axis=1)
rows_with_NaN = spoty_df[row_has_NaN]
rows_with_NaN
# Out:
#                                        title artist  danceability  energy  \
# 1851  Atencion Les Habla La Policia Original    NaN         0.542   0.793
# 1852     INTRO PARA Dj´s (PARA MIX) (3 de 4)    NaN         0.542   0.793
# 2593                                     NaN    NaN         0.745   0.869
# 5865                                     NaN    NaN         0.714   0.821
# 8977                                     NaN    NaN         0.727   0.401
#
#       key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 1851  8.0    -8.203   1.0       0.0530        0.0423          0.000004
# 1852  8.0    -8.203   1.0       0.0530        0.0423          0.000004
# 2593  6.0    -6.913   0.0       0.0369        0.0233          0.001870
# 5865  6.0    -7.635   1.0       0.1760        0.0410          0.000000
# 8977  9.0    -6.696   1.0       0.0657        0.3090          0.000000
#
#       liveness  valence    tempo                      id  \
# 1851    0.0814    0.708  173.931  0yfNXxlyXdmP0ue1iJijx1
# 1852    0.0814    0.708  173.931  0yfNXxlyXdmP0ue1iJijx1
# 2593    0.1340    0.870  126.989  10ZwI7HcqEIPsxQ1lUtobL
# 5865    0.1160    0.649   95.999  69gRFGOWY9OMpFJgFol1u0
# 8977    0.0572    0.793   91.999  2Wq9wjMTn2qD1zlfRYJtv8
#
#                                        uri  duration_ms  category
# 1851  spotify:track:0yfNXxlyXdmP0ue1iJijx1     256520.0         0
# 1852  spotify:track:0yfNXxlyXdmP0ue1iJijx1     256520.0         0
# 2593  spotify:track:10ZwI7HcqEIPsxQ1lUtobL     284862.0         2
# 5865  spotify:track:69gRFGOWY9OMpFJgFol1u0     282707.0         0
# 8977  spotify:track:2Wq9wjMTn2qD1zlfRYJtv8     155054.0         0

# %%
spoty_df = spoty_df.reset_index()

# %%
spoty_df = spoty_df.iloc[:,1:]

# %%
hot_songs_df.to_csv("../data/hotsongs_db.csv")

# %%
spoty_df.to_csv("../data/spotify_db.csv")
